# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
from StringIO import StringIO

# %%
# !julia -e 'versioninfo()'
# Out:
# Julia Version 0.4.0-rc4
# Commit e9c9c92* (2015-10-04 03:14 UTC)
# Platform Info:
#   System: Darwin (x86_64-apple-darwin14.5.0)
#   CPU: Intel(R) Core(TM) i5-4288U CPU @ 2.60GHz
#   WORD_SIZE: 64
#   BLAS: libopenblas (USE64BITINT DYNAMIC_ARCH NO_AFFINITY Haswell)
#   LAPACK: libopenblas64_
#   LIBM: libopenlibm
#   LLVM: libLLVM-3.3

# %%
bench = !julia benchmark.jl
bench = "\n".join(bench)
bench = pd.read_table(StringIO(bench))

# %%
bench
# Out:
#         size  construction       minimum       maximum         push!  \
# 0        100      0.000004  4.920000e-09  4.900000e-09  6.700000e-08
# 1        183      0.000008  5.870000e-09  5.930000e-09  8.580000e-08
# 2        335      0.000014  5.940000e-09  5.890000e-09  1.210000e-07
# 3        615      0.000026  5.970000e-09  6.030000e-09  4.105000e-07
# 4       1128      0.000046  5.460000e-09  5.500000e-09  5.165000e-07
# 5       2069      0.000076  4.960000e-09  4.960000e-09  7.978000e-07
# 6       3792      0.000138  5.020000e-09  4.980000e-09  1.365500e-06
# 7       6951      0.000259  5.070000e-09  4.940000e-09  4.849000e-07
# 8      12742      0.000438  4.860000e-09  4.830000e-09  6.820000e-07
# 9      23357      0.000784  5.110000e-09  4.890000e-09  1.166500e-06
# 10     42813      0.001506  4.950000e-09  5.030000e-09  2.425700e-06
# 11     78475      0.002675  5.030000e-09  5.090000e-09  4.417900e-06
# 12    143844      0.004946  5.000000e-09  5.290000e-09  8.957100e-06
# 13    263665      0.008966  4.880000e-09  5.560000e-09  8.239500e-06
# 14    483293      0.016961  5.800000e-09  5.570000e-09  1.017440e-05
# 15    885866      0.033267  5.510000e-09  6.210000e-09  2.179330e-05
# 16   1623776      0.061713  6.490000e-09  5.940000e-09  1.351370e-05
# 17   2976351      0.124734  6.230000e-09  6.020000e-09  2.896845e-04
# 18   5455594      0.246592  6.060000e-09  6.640000e-09  1.564830e-03
# 19  10000000      0.424723  6.540000e-09  6.030000e-09  5.180280e-05
#
#          popmin!       popmax!
# 0   1.683000e-07  1.626000e-07
# 1   2.163000e-07  2.222000e-07
# 2   2.391000e-07  2.380000e-07
# 3   2.444000e-07  2.486000e-07
# 4   2.288000e-07  2.369000e-07
# 5   2.590000e-07  2.556000e-07
# 6   2.628000e-07  2.824000e-07
# 7   2.860000e-07  3.019000e-07
# 8   3.109000e-07  3.334000e-07
# 9   3.381000e-07  3.561000e-07
# 10  3.608000e-07  4.097000e-07
# 11  4.230000e-07  4.575000e-07
# 12  4.496000e-07  4.926000e-07
# 13  5.111000e-07  5.208000e-07
# 14  5.901000e-07  6.249000e-07
# 15  7.684000e-07  7.704000e-07
# 16  8.156000e-07  8.355000e-07
# 17  9.442000e-07  9.584000e-07
# 18  1.072000e-06  1.042700e-06
# 19  1.179200e-06  1.200000e-06

# %%
figsize(12, 8)

# %%
bench.plot(x="size", logy=True, linestyle="--", marker="o")

# %%
bench.plot(x="size", y="construction", linestyle="--", marker="o")

# %%
bench.plot(x="size", y=["minimum", "maximum"], linestyle="--", marker="o")

# %%
bench.plot(x="size", y="push!", linestyle="--", marker="o")

# %%
bench.plot(x="size", y=["popmin!", "popmax!"], linestyle="--", marker="o")
